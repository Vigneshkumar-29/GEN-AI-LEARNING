# %%
# !pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    --------------------------------- ------ 524.3/625.0 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 625.0/625.0 kB 1.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.7 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/6 [tqdm]
#    ------------- -------------------------- 2/6 [defusedxml]
# ...

# %%
from textblob import TextBlob # its an python module textblob(module)  TextBlob (class)
