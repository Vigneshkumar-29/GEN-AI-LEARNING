# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vigne\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %% [markdown]
# to remove the unwanted words like a , the , was , shell , ect ..........

# %%
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
stop_words
# print(len(stop_words))
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
f = open(r'D:\Code\Gen-AI\Text_normalization\data.txt','r',encoding='utf-8')
f.read()
# Out:
# '1.Machine Learning (ML) and Deep    😂😂          Learning (DL) are both important      subsets of artificial intelligence, but they serve different purposes and approaches. Let\'s break down each concept with real-time examples:\n\n### Machine Learning (ML):\n\n**Definition:**\nMachine Learning is a type of AI that allows computers to automatically learn and improve from experience without being explicitly programmed. This means that algorithms can be trained to recognize patterns in data and make predictions or decisions.\n\n**Key Concepts:**\n- **Supervised Learning:** Where a model is trained on labeled data to predict outcomes. Example: Image classification (distinguishing between different types of objects).\n- **Unsupervised Learning:** Where the model finds patterns in data without being told what to look for. Example: Clustering (grouping similar items together).\n- **Reinforcement Learning:** Where an agent learns by interacting with an environment, trying to maximize a reward. Example: Self-driving cars that learn to navigate and make decisions based on feedback.\n\n**Real-Time Example:**\nImagine a self-driving car. To make it drive safely, it must learn from its experiences. The car uses sensors like cameras and radar to detect objects and obstacles in real-time. It then uses machine learning algorithms to predict where other cars might be based on the information it has collected. This allows the car to make informed decisions about when to slow down, stop, or even change lanes to avoid accidents.\n\n### Deep Learning (DL):\n\n**Definition:**\nDeep Learning is a specific type of machine learning that uses neural networks with many layers (hence the "deep" in DL). These layers enable more complex features to be extracted from data.\n\n**Key Concepts:**\n- **Neural Networks:** These are layers of interconnected nodes that process information. In DL, these nodes are organized in a hierarchy, enabling the model to extract features at different levels of abstraction. Example: Convolutional Neural Networks (CNNs) used in image recognition.\n- **Autoencoders:** A type of neural network used for both compression and reconstruction of data. Example: Used in natural language processing for reducing text to a simpler form for easier understanding.\n\n**Real-Time Example:**\nConsider a smart assistant like Siri or Google Assistant. This system uses a combination of ML and DL to understand what you\'re saying. It uses natural language processing (NLP) algorithms to break down sentences into words and context. Deep learning is applied in recognizing entities and entities within sentences. For example, if you ask Siri to call your friend, the DL system identifies the entities (e.g., "John Smith"), extracts the relevant context (e.g., the time and place), and constructs the appropriate response.\n\nIn summary, Machine Learning is about making machines better at tasks that humans would need a lot of practice to do, while Deep Learning is about making machines better at recognizing complex patterns and features in data, which is essential for understanding and interpreting the world around us. Both are crucial for advancing technology, but they tackle different types of challenges and applications.'

# %%
from nltk.corpus import stopwords

f = open('data.txt','r',encoding='utf-8')
text = f.read()

words = text.split()

stop_words=stopwords.words('english')
clean_words = []
for word in words:
    if word not in stop_words:
        clean_words.append(word)
text = " ".join(clean_words)
print(text)
f.close()
# Out:
# Machine Learning (ML) Deep 😂😂 Learning (DL) important subsets artificial intelligence, serve different purposes approaches. Let's break concept real-time examples: ### Machine Learning (ML): **Definition:** Machine Learning type AI allows computers automatically learn improve experience without explicitly programmed. This means algorithms trained recognize patterns data make predictions decisions. **Key Concepts:** - **Supervised Learning:** Where model trained labeled data predict outcomes. Example: Image classification (distinguishing different types objects). - **Unsupervised Learning:** Where model finds patterns data without told look for. Example: Clustering (grouping similar items together). - **Reinforcement Learning:** Where agent learns interacting environment, trying maximize reward. Example: Self-driving cars learn navigate make decisions based feedback. **Real-Time Example:** Imagine self-driving car. To make drive safely, must learn experiences. The car uses sensors like cameras radar detect objects obstacles real-time. It uses machine learning algorithms predict cars might based information collected. This allows car make informed decisions slow down, stop, even change lanes avoid accidents. ### Deep Learning (DL): **Definition:** Deep Learning specific type machine learning uses neural networks many layers (hence "deep" DL). These layers enable complex features extracted data. **Key Concepts:** - **Neural Networks:** These layers interconnected nodes process information. In DL, nodes organized hierarchy, enabling model extract features different levels abstraction. Example: Convolutional Neural Networks (CNNs) used image recognition. - **Autoencoders:** A type neural network used compression reconstruction data. Example: Used natural language processing reducing text simpler form easier understanding. **Real-Time Example:** Consider smart assistant like Siri Google Assistant. This system uses combination ML DL understand saying. It uses natural language processing (NLP) algorithms break sentences words context. Deep learning applied recognizing entities entities within sentences. For example, ask Siri call friend, DL system identifies entities (e.g., "John Smith"), extracts relevant context (e.g., time place), constructs appropriate response. In summary, Machine Learning making machines better tasks humans would need lot practice do, Deep Learning making machines better recognizing complex patterns features data, essential understanding interpreting world around us. Both crucial advancing technology, tackle different types challenges applications.

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(data)
