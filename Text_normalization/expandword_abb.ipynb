# %%
 #pip install contractions

# %% [markdown]
# with help of contraction we can expand the words to I'm -> I am
#
# didn't -> did not
# din't -> din't   ----------  it's an invalid words so it can not expand it .
#
# it only give the full form for the few things only not for all the things
#
# ML -> it didn't expand this , as we known it doesn't expand all the things (Machine Learning)
#
# this is process is happened before the removing the special characters and punctuations

# %%
import contractions

# %%
import string

# %%
print(string.punctuation)
str_punctuation = string.punctuation
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
import re

data = open('data.txt',encoding='utf-8').read()
print(data)
# Out:
# 1.Machine Learning (ML) and Deep    😂😂          Learning (DL) are both important      subsets of artificial intelligence, but they serve different purposes and approaches. Let's break down each concept with real-time examples:
#
# ### Machine Learning (ML):
#
# **Definition:**
# Machine Learning is a type of AI that allows computers to automatically learn and improve from experience without being explicitly programmed. This means that algorithms can be trained to recognize patterns in data and make predictions or decisions.
#
# **Key Concepts:**
# - **Supervised Learning:** Where a model is trained on labeled data to predict outcomes. Example: Image classification (distinguishing between different types of objects).
# - **Unsupervised Learning:** Where the model finds patterns in data without being told what to look for. Example: Clustering (grouping similar items together).
# ...

# %%
temp = re.findall(f'[{str_punctuation}]',data)  

# f'[{str_punctuation}]' why we give this inside the f'[{   }] because it contain multiple value like symbols so we give this as an list of str_punctuation

# %%
temp = re.sub(f'[{str_punctuation}]','',data)
temp
# Out:
# '1Machine Learning ML and Deep    😂😂          Learning DL are both important      subsets of artificial intelligence but they serve different purposes and approaches Lets break down each concept with realtime examples\n\n Machine Learning ML\n\nDefinition\nMachine Learning is a type of AI that allows computers to automatically learn and improve from experience without being explicitly programmed This means that algorithms can be trained to recognize patterns in data and make predictions or decisions\n\nKey Concepts\n Supervised Learning Where a model is trained on labeled data to predict outcomes Example Image classification distinguishing between different types of objects\n Unsupervised Learning Where the model finds patterns in data without being told what to look for Example Clustering grouping similar items together\n Reinforcement Learning Where an agent learns by interacting with an environment trying to maximize a reward Example Selfdriving cars that learn to navigate and mak
# ...
