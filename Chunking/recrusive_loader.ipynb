# %%
pip install langchain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (1.3.16)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain) (1.6.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.14.2)
# Requirement already satisfied: certifi in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.3)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain_text_splitters
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain_text_splitters
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain_text_splitters) (1.6.0)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (4.14.2)
# Requirement already satisfied: certifi in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.0.9)
# Requirement already satisfied: idna in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.7.0)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: langchain_text_splitters
# Successfully installed langchain_text_splitters-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
with open('data.txt','r',encoding='utf-8') as file:
    data=file.read()

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 200,
    chunk_overlap = 40,
    separators = ['\n\n','.','\n',''] # we can use any symbol like ! , 
)
chunk = text_splitter.split_text(data)
print(type(chunk),chunk)
# Out:
# <class 'list'> ['Big data collects large datasets from distributed sources using distributed storage and parallel computation', '.\nGenerative AI processes high volume information in real time using distributed storage and parallel computation', '.\nA big data pipeline stores structured and unstructured records using distributed storage and parallel computation', '.\nText normalization normalizes noisy text before model training using distributed storage and parallel computation', '.\nLemmatization converts words into meaningful linguistic forms using distributed storage and parallel computation', '.\nNatural language processing removes unnecessary punctuation and symbols using distributed storage and parallel computation', '.\nA data engineer handles spelling variations across documents using distributed storage and parallel computation', '.\nA language model prepares textual data for generative models using distributed storage and parallel computation', '.\nAn enterprise AI system analyzes customer messages and product reviews using distributed storage and parallel computation', '.\nA preprocessing workflow extracts useful patterns from large document collections using distributed storage and parallel computation', '.\nBig data reduces vocabulary variation during preprocessing using distributed storage and parallel computation', '.\nGenerative AI improves the consistency of training data using distributed storage and parallel computation', '.\nA big data pipeline supports scalable analytics across distributed systems using distributed storage and parallel computation', '.\nText normalization uses pipelines to transform raw textual records using distributed storage and parallel computation', '.\nLemmatization helps language models understand user instructions using distributed storage and parallel computation', '.\nNatural language processing cleans duplicate and incomplete documents using distributed storage and parallel computation', '.\nA data engineer identifies meaningful terms in large corpora using distributed storage and parallel computation', '.\nA language model supports semantic search over enterprise documents using distributed storage and parallel computation', '.\nAn enterprise AI system improves retrieval quality for question answering using distributed storage and parallel computation', '.\nA preprocessing workflow prepares text for embedding generation using distributed storage and parallel computation', '.\nBig data collects large datasets from distributed sources before tokenization and vector representation', '.\nGenerative AI processes high volume information in real time before tokenization and vector representation', '.\nA big data pipeline stores structured and unstructured records before tokenization and vector representation', '.\nText normalization normalizes noisy text before model training before tokenization and vector representation', '.\nLemmatization converts words into meaningful linguistic forms before tokenization and vector representation', '.\nNatural language processing removes unnecessary punctuation and symbols before tokenization and vector representation', '.\nA data engineer handles spelling variations across documents before tokenization and vector representation', '.\nA language model prepares textual data for generative models before tokenization and vector representation', '.\nAn enterprise AI system analyzes customer messages and product reviews before tokenization and vector representation', '.\nA preprocessing workflow extracts useful patterns from large document collections before tokenization and vector representation', '.\nBig data reduces vocabulary variation during preprocessing before tokenization and vector representation', '.\nGenerative AI improves the consistency of training data before tokenization and vector representation', '.\nA big data pipeline supports scalable analytics across distributed systems before tokenization and vector representation', '.\nText norma ...
