# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(
    model = 'gemini-3.5-flash',
    api_key = "api key"
)

# %%
response = llm.invoke('''Explain prompt types ?''')
#send the request to gemini and get back the response
response
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# AIMessage(content=[{'type': 'text', 'text': 'In generative AI (like ChatGPT, Claude, or Midjourney), a **prompt** is the input (text, instruction, or image) you give to the AI to get a specific output. \n\nPrompts can be categorized in several ways based on **how they are structured**, **their purpose**, and **the logic they require**. Here is a comprehensive guide to the different types of prompts.\n\n---\n\n### Category 1: Based on Examples (The "Shot" Prompts)\nThese prompts are categorized by how many examples of the desired output you show the AI.\n\n*   **1. Zero-Shot Prompting:**\n    *   **What it is:** You ask the AI to perform a task without giving it any examples. It relies entirely on its pre-trained knowledge.\n    *   **Example:** *"Translate \'Where is the library?\' into French."*\n*   **2. One-Shot Prompting:**\n    *   **What it is:** You provide exactly *one* example of the desired output format before asking the question.\n    *   **Example:** \n        > *Input: "Happy" -> Output: "Sad"*  \n        > *Input: "Hot" -> Output:* [AI completes: *"Cold"*]\n*   **3. Few-Shot Prompting:**\n    *   **What it is:** You provide multiple examples (usually 3 to 5) to show a pattern, tone, or complex formatting you want the AI to follow.\n    *   **Example:**\n        > *Review: "The food was amazing!" -> Sentiment: Positive*  \n        > *Review: "It took two hours to get our food." -> Sentiment: Negative*  \n        > *Review: "The atmosphere was okay." -> Sentiment: Neutral*  \n        > *Review: "I will never come back here." -> Sentiment:* [AI completes: *"Negative"*]\n\n---\n\n### Category 2: Based on Reasoning & Logic\nThese prompts are used to help the AI handle complex problem-solving, math, or deep analysis.\n\n*   **4. Chain-of-Thought (CoT) Prompting:**\n    *   **What it is:** You ask the AI to explain its step-by-step thinking process before giving the final answer. This drastically reduces AI math and logic errors.\n    *   **Example:** *"If Sally has 5 apples, eats 2, and buys 4 more, how many does she have? **Let’s think step-by-step.**"*\n*   **5. Tree of Thoughts (ToT) Prompting:**\n    *   **What it is:** A more advanced version of CoT where you instruct the AI to generate multiple different reasoning paths, evaluate them, and self-correct to find the best solution.\n    *   **Example:** *"Explore three different ways to solve this business logistics problem. Evaluate the pros and cons of each, and then decide on the optimal path."*\n\n---\n\n### Category 3: Based on Purpose & Style\nThese are the most common prompts used in daily work and creative tasks.\n\n*   **6. Role-Playing / Persona Prompts:**\n    *   **What it is:** You tell the AI to adopt a specific identity, profession, or personality. This changes the tone, depth, and vocabulary of the response.\n    *   **Example:** *"Act as a cynical, senior software engineer. Review this code and point out the flaws."*\n*   **7. Instructional / Direct Prompts:**\n    *   **What it is:** A straightforward command telling the AI exactly what to do and how to format it.\n    *   **Example:** *"Summarize this article in 3 bullet points, using simple language suitable for a 10-year-old."*\n*   **8. Constraint-Based Prompts:**\n    *   **What it is:** You set strict rules or boundaries on what the AI *cannot* do.\n    *   **Example:** *"Write a product description for a smartphone, but do not use the words \'revolutionary,\' \'groundbreaking,\' or \'innovative.\' Limit it to 50 words."*\n\n---\n\n### Category 4: Interactive & Conversational\nThese prompts are designed to create a back-and-forth dialogue between you and the AI.\n\n*   **9. Socratic / Interview Prompts:**\n    *   **What it is:** You ask the AI to interview *you* to gather information before it generates a final output.\n    *   **Example:** *"I want you to write a resume for me. Ask me 5 questions, one at a time, about my experience. After I answer all five, generate the resume."*\n*   **10 ...

# %%
response.content
# Out:
# [{'type': 'text',
#   'text': 'In generative AI (like ChatGPT, Claude, or Midjourney), a **prompt** is the input (text, instruction, or image) you give to the AI to get a specific output. \n\nPrompts can be categorized in several ways based on **how they are structured**, **their purpose**, and **the logic they require**. Here is a comprehensive guide to the different types of prompts.\n\n---\n\n### Category 1: Based on Examples (The "Shot" Prompts)\nThese prompts are categorized by how many examples of the desired output you show the AI.\n\n*   **1. Zero-Shot Prompting:**\n    *   **What it is:** You ask the AI to perform a task without giving it any examples. It relies entirely on its pre-trained knowledge.\n    *   **Example:** *"Translate \'Where is the library?\' into French."*\n*   **2. One-Shot Prompting:**\n    *   **What it is:** You provide exactly *one* example of the desired output format before asking the question.\n    *   **Example:** \n        > *Input: "Happy" -> Output: "Sad"*  \n        > *Input: "Hot" -> Output:* [AI completes: *"Cold"*]\n*   **3. Few-Shot Prompting:**\n    *   **What it is:** You provide multiple examples (usually 3 to 5) to show a pattern, tone, or complex formatting you want the AI to follow.\n    *   **Example:**\n        > *Review: "The food was amazing!" -> Sentiment: Positive*  \n        > *Review: "It took two hours to get our food." -> Sentiment: Negative*  \n        > *Review: "The atmosphere was okay." -> Sentiment: Neutral*  \n        > *Review: "I will never come back here." -> Sentiment:* [AI completes: *"Negative"*]\n\n---\n\n### Category 2: Based on Reasoning & Logic\nThese prompts are used to help the AI handle complex problem-solving, math, or deep analysis.\n\n*   **4. Chain-of-Thought (CoT) Prompting:**\n    *   **What it is:** You ask the AI to explain its step-by-step thinking process before giving the final answer. This drastically reduces AI math and logic errors.\n    *   **Example:** *"If Sally has 5 apples, eats 2, and buys 4 more, how many does she have? **Let’s think step-by-step.**"*\n*   **5. Tree of Thoughts (ToT) Prompting:**\n    *   **What it is:** A more advanced version of CoT where you instruct the AI to generate multiple different reasoning paths, evaluate them, and self-correct to find the best solution.\n    *   **Example:** *"Explore three different ways to solve this business logistics problem. Evaluate the pros and cons of each, and then decide on the optimal path."*\n\n---\n\n### Category 3: Based on Purpose & Style\nThese are the most common prompts used in daily work and creative tasks.\n\n*   **6. Role-Playing / Persona Prompts:**\n    *   **What it is:** You tell the AI to adopt a specific identity, profession, or personality. This changes the tone, depth, and vocabulary of the response.\n    *   **Example:** *"Act as a cynical, senior software engineer. Review this code and point out the flaws."*\n*   **7. Instructional / Direct Prompts:**\n    *   **What it is:** A straightforward command telling the AI exactly what to do and how to format it.\n    *   **Example:** *"Summarize this article in 3 bullet points, using simple language suitable for a 10-year-old."*\n*   **8. Constraint-Based Prompts:**\n    *   **What it is:** You set strict rules or boundaries on what the AI *cannot* do.\n    *   **Example:** *"Write a product description for a smartphone, but do not use the words \'revolutionary,\' \'groundbreaking,\' or \'innovative.\' Limit it to 50 words."*\n\n---\n\n### Category 4: Interactive & Conversational\nThese prompts are designed to create a back-and-forth dialogue between you and the AI.\n\n*   **9. Socratic / Interview Prompts:**\n    *   **What it is:** You ask the AI to interview *you* to gather information before it generates a final output.\n    *   **Example:** *"I want you to write a resume for me. Ask me 5 questions, one at a time, about my experience. After I answer all five, generate the resume."*\n*   **10. Iterative / Refinement Prompts:* ...
#   'extras': {'signature': '...'}}]

# %%
response.content[0]['text']
# Out:
# 'In generative AI (like ChatGPT, Claude, or Midjourney), a **prompt** is the input (text, instruction, or image) you give to the AI to get a specific output. \n\nPrompts can be categorized in several ways based on **how they are structured**, **their purpose**, and **the logic they require**. Here is a comprehensive guide to the different types of prompts.\n\n---\n\n### Category 1: Based on Examples (The "Shot" Prompts)\nThese prompts are categorized by how many examples of the desired output you show the AI.\n\n*   **1. Zero-Shot Prompting:**\n    *   **What it is:** You ask the AI to perform a task without giving it any examples. It relies entirely on its pre-trained knowledge.\n    *   **Example:** *"Translate \'Where is the library?\' into French."*\n*   **2. One-Shot Prompting:**\n    *   **What it is:** You provide exactly *one* example of the desired output format before asking the question.\n    *   **Example:** \n        > *Input: "Happy" -> Output: "Sad"*  \n        > *Input: "Hot" -> Output:* [AI completes: *"Cold"*]\n*   **3. Few-Shot Prompting:**\n    *   **What it is:** You provide multiple examples (usually 3 to 5) to show a pattern, tone, or complex formatting you want the AI to follow.\n    *   **Example:**\n        > *Review: "The food was amazing!" -> Sentiment: Positive*  \n        > *Review: "It took two hours to get our food." -> Sentiment: Negative*  \n        > *Review: "The atmosphere was okay." -> Sentiment: Neutral*  \n        > *Review: "I will never come back here." -> Sentiment:* [AI completes: *"Negative"*]\n\n---\n\n### Category 2: Based on Reasoning & Logic\nThese prompts are used to help the AI handle complex problem-solving, math, or deep analysis.\n\n*   **4. Chain-of-Thought (CoT) Prompting:**\n    *   **What it is:** You ask the AI to explain its step-by-step thinking process before giving the final answer. This drastically reduces AI math and logic errors.\n    *   **Example:** *"If Sally has 5 apples, eats 2, and buys 4 more, how many does she have? **Let’s think step-by-step.**"*\n*   **5. Tree of Thoughts (ToT) Prompting:**\n    *   **What it is:** A more advanced version of CoT where you instruct the AI to generate multiple different reasoning paths, evaluate them, and self-correct to find the best solution.\n    *   **Example:** *"Explore three different ways to solve this business logistics problem. Evaluate the pros and cons of each, and then decide on the optimal path."*\n\n---\n\n### Category 3: Based on Purpose & Style\nThese are the most common prompts used in daily work and creative tasks.\n\n*   **6. Role-Playing / Persona Prompts:**\n    *   **What it is:** You tell the AI to adopt a specific identity, profession, or personality. This changes the tone, depth, and vocabulary of the response.\n    *   **Example:** *"Act as a cynical, senior software engineer. Review this code and point out the flaws."*\n*   **7. Instructional / Direct Prompts:**\n    *   **What it is:** A straightforward command telling the AI exactly what to do and how to format it.\n    *   **Example:** *"Summarize this article in 3 bullet points, using simple language suitable for a 10-year-old."*\n*   **8. Constraint-Based Prompts:**\n    *   **What it is:** You set strict rules or boundaries on what the AI *cannot* do.\n    *   **Example:** *"Write a product description for a smartphone, but do not use the words \'revolutionary,\' \'groundbreaking,\' or \'innovative.\' Limit it to 50 words."*\n\n---\n\n### Category 4: Interactive & Conversational\nThese prompts are designed to create a back-and-forth dialogue between you and the AI.\n\n*   **9. Socratic / Interview Prompts:**\n    *   **What it is:** You ask the AI to interview *you* to gather information before it generates a final output.\n    *   **Example:** *"I want you to write a resume for me. Ask me 5 questions, one at a time, about my experience. After I answer all five, generate the resume."*\n*   **10. Iterative / Refinement Prompts:**\n    *   ...
