# %%
from langchain_ollama import ChatOllama

# %%
model = ChatOllama(
    model="qwen2.5:1.5b"
)

# %%
response = model.invoke(''' Explain Machine Learning and Explain Deep Learning with real-time example''')

# %%
print(response.content)
# Out:
# Machine Learning (ML) and Deep Learning (DL) are both important subsets of artificial intelligence, but they serve different purposes and approaches. Let's break down each concept with real-time examples:
#
# ### Machine Learning (ML):
#
# **Definition:**
# Machine Learning is a type of AI that allows computers to automatically learn and improve from experience without being explicitly programmed. This means that algorithms can be trained to recognize patterns in data and make predictions or decisions.
#
# **Key Concepts:**
# - **Supervised Learning:** Where a model is trained on labeled data to predict outcomes. Example: Image classification (distinguishing between different types of objects).
# - **Unsupervised Learning:** Where the model finds patterns in data without being told what to look for. Example: Clustering (grouping similar items together).
# ...

# %% [markdown]
# # Task
# LLM - detect the user language and explain the context in english
# output :
# Detected language:
# Explanation:

# %%
response = model.invoke(''' understand the user input and identify the user input language name 
                            Then explain the content for the users input in english 
                            पायथन प्रोग्रामिंग?   ''')
print(response.content)
# Out:
# **User Input Language Name:** Hindi
#
# **Content in English:** "What is Python programming?"
#
# Python programming is a high-level programming language that is widely used for web development, data analysis, artificial intelligence, automation, and other applications. It is known for its simplicity and readability, making it a popular choice for beginners and professionals alike. Python is often used in conjunction with frameworks like Django, Flask, and Pyramid, which provide structure and tools for building web applications.
