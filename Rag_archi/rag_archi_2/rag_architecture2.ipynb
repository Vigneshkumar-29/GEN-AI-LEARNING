# %%
# !pip install langchain_huggingface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain_huggingface) (1.29.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain_huggingface) (1.6.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain_huggingface) (0.23.2)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.32.5)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.70.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.16.0)
# Requirement already satisfied: anyio in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.14.2)
# Requirement already satisfied: certifi in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.11.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.7.0)
# Requirement already satisfied: colorama in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.4.6)
# Downloading langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Installing collected packages: langchain_huggingface
# Successfully installed langchain_huggingface-1.2.2

# %%
# !pip install langchain_community
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain_community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.14.3-cp314-cp314-win_amd64.whl.metadata (8.5 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain_community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain_community) (1.6.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain_community) (0.11.1)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain_community) (2.5.1)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain_community) (2.34.2)
# Collecting sqlalchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.52-cp314-cp314-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain_community) (9.1.4)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading propcache-0.5.2-cp314-cp314-win_amd64.whl.metadata (17 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading yarl-1.24.5-cp314-cp314-win_amd64.whl.metadata (107 kB)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (26.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (4.14.2)
# Requirement already satisfied: certifi in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (1.0.9)
# Requirement already satisfied: idna in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (0.4.4)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain_community)
#   Downloading python_dotenv-1.2.3-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\vigne\AppData\Roaming\Python\Python314\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.7.0)
# Collecting greenlet>=1 (from sqlalchemy<3.0.0,>=1.4.0->langchain_community)
#   Downloading greenlet-3.5.5-cp314-cp314-win_amd64.whl.metadata (3.9 kB)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------  2.4/2.4 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 11.5 MB/s  0:00:00
# Downloading aiohttp-3.14.3-cp314-cp314-win_amd64.whl (481 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 14.2 MB/s  0:00:00
# Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl (45 kB)
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
# Downloading sqlalchemy-2.0.52-cp314-cp314-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 11.0 MB/s  0:00:00
# Downloading yarl-1.24.5-cp314-cp314-win_amd64.whl (99 kB)
# Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl (44 kB)
# Downloading greenlet-3.5.5-cp314-cp314-win_amd64.whl (327 kB)
# Downloading propcache-0.5.2-cp314-cp314-win_amd64.whl (42 kB)
# Downloading python_dotenv-1.2.3-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, propcache, multidict, httpx-sse, greenlet, frozenlist, aiohappyeyeballs, yarl, sqlalchemy, aiosignal, pydantic-settings, aiohttp, langchain-classic, langchain_community
#
#    ----------------------------------------  0/14 [python-dotenv]
#    -- -------------------------------------  1/14 [propcache]
#    -------- -------------------------------  3/14 [httpx-sse]
#    ----------- ----------------------------  4/14 [greenlet]
#    ----------- ----------------------------  4/14 [greenlet]
#    ----------- ----------------------------  4/14 [greenlet]
#    ----------- ----------------------------  4/14 [greenlet]
#    -------------------- -------------------  7/14 [yarl]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------- -----------------  8/14 [sqlalchemy]
#    ---------------------------- ----------- 10/14 [pydantic-settings]
#    ---------------------------- ----------- 10/14 [pydantic-settings]
#    ---------------------------- ----------- 10/14 [pydantic-settings]
#    ------------------------------- -------- 11/14 [aiohttp]
#    ------------------------------- -------- 11/14 [aiohttp]
#    ------------------------------- -------- 11/14 [aiohttp]
#    ------------------------------- -------- 11/14 [aiohttp]
#    ------------------------------- -------- 11/14 [aiohttp]
#    ------------------------------- -------- 11/14 [aiohttp]
#    ------------------------------- -------- 11/14 [aiohttp]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ---------------------------------- ----- 12/14 [langchain-classic]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ------------------------------------- -- 13/14 [langchain_community]
#    ---------------------------------------- 14/14 [langchain_community]
#
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.3 aiosignal-1.4.0 frozenlist-1.8.0 greenlet-3.5.5 httpx-sse-0.4.3 langchain-classic-1.0.8 langchain_community-0.4.2 multidict-6.7.1 propcache-0.5.2 pydantic-settings-2.15.0 python-dotenv-1.2.3 sqlalchemy-2.0.52 yarl-1.24.5

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from sentence_transformers import SentenceTransformer
import faiss
import spacy
import re
import contractions
from textblob import TextBlob
# Out:
# C:\Users\vigne\AppData\Local\Temp\ipykernel_20168\4218474087.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS

# %% [markdown]
# 1. Load the document(.txt)

# %%
data=open('data.txt').read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data=open('data.txt').read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.txt'

# %% [markdown]
# 2. Text Normalization

# %%
data=data.lower()

# %%
data=re.sub(r'\s{2,}',' ',data)

# %%
import contractions
data=contractions.fix(data)

# %%
import emoji
data=emoji.replace_emoji(data,'')

# %%
import string
str_punc=string.punctuation.replace('.','')
data=data.translate(str.maketrans('','',str_punc))

# %%
data=re.sub(r'[^A-Za-z0-9\s\.]','',data)

# %%
values=TextBlob(data).correct()
values
# Out:
# TextBlob("1.machine learning my and deep a  learning do are both important subjects of artificial intelligence but they serve different purposes and approaches. let us break down each concept with realize examples  machine learning my definition
# machine learning is a type of ai that allows computers to automatically learn and improve from experience without being explicitly programme. this means that algorithms can be trained to recognize patterns in data and make predictions or decisions. key concepts
#  supervised learning where a model is trained on labelled data to predict outcome. example image classification distinguishing between different types of objects.
#  supervised learning where the model finds patterns in data without being told what to look for. example fluttering grouping similar items together.
#  reinforcement learning where an agent learns by interesting with an environment trying to minimize a reward. example selfdriving cars that learn to navigable and make decisions based on feedback. realize example
# imagine a selfdriving car. to make it drive safely it must learn from its experiences. the car uses sensory like camera and rear to detect objects and obstacles in realize. it then uses machine learning algorithms to predict where other cars might be based on the information it has collected. this allows the car to make informed decisions about when to slow down stop or even change lanes to avoid accidents.  deep learning do definition
# deep learning is a specific type of machine learning that uses neutral network with many layers hence the deep in do. these layers enable more complex features to be extracted from data. key concepts
#  neutral network these are layers of interconnected nodes that process information. in do these nodes are organized in a hierarchy enabling the model to extract features at different levels of abstraction. example convolutional neutral network enns used in image recognition.
#  autoencoders a type of neutral network used for both compression and reconstruction of data. example used in natural language processing for reducing text to a simpler form for easier understanding. realize example
# consider a smart assistant like sir or goose assistant. this system uses a combination of my and do to understand what you are saying. it uses natural language processing nap algorithms to break down sentences into words and context. deep learning is applied in recognizing entitles and entitles within sentences. for example if you ask sir to call your friend the do system identified the entitles e.g. john smith extracts the relevant context e.g. the time and place and construct the appropriate response. in summary machine learning is about making machines better at tasks that humans would need a lot of practice to do while deep learning is about making machines better at recognizing complex patterns and features in data which is essential for understanding and interpreting the world around us. both are crucial for advancing technology but they tackle different types of challenges and applications.")

# %% [markdown]
# Lemmatization

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
tokens=nlp(data)
updated_tokens=[token.lemma_ for token in tokens if not token.is_stop]
data=' '.join(updated_tokens).strip()
data
# Out:
# '1.machine learn ml deep   learning dl important subset artificial intelligence serve different purpose approach . let break concept realtime example   machine learning ml definition \n machine learning type ai allow computer automatically learn improve experience explicitly program . mean algorithm train recognize pattern datum prediction decision . key concept \n  supervise learning model train label datum predict outcome . example image classification distinguish different type object . \n  unsupervised learning model find pattern datum tell look . example cluster group similar item . \n  reinforcement learning agent learn interact environment try maximize reward . example selfdrive car learn navigate decision base feedback . realtime example \n imagine selfdriving car . drive safely learn experience . car use sensor like camera radar detect object obstacle realtime . use machine learn algorithm predict car base information collect . allow car informed decision slow stop change lane avoid accident .   deep learning dl definition \n deep learning specific type machine learning use neural network layer deep dl . layer enable complex feature extract datum . key concept \n  neural network layer interconnect node process information . dl node organize hierarchy enable model extract feature different level abstraction . example convolutional neural network cnn image recognition . \n  autoencoder type neural network compression reconstruction datum . example natural language processing reduce text simple form easy understanding . realtime example \n consider smart assistant like siri google assistant . system use combination ml dl understand say . use natural language processing nlp algorithm break sentence word context . deep learning apply recognize entity entity sentence . example ask siri friend dl system identify entity e.g. john smith extract relevant context e.g. time place construct appropriate response . summary machine learning make machine well task human need lot practice deep learning make machine well recognize complex pattern feature datum essential understanding interpret world . crucial advance technology tackle different type challenge application .'

# %% [markdown]
# Chunking

# %%
splitter=RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=40
)
chunks=list(set(splitter.split_text(data)))

# %% [markdown]
# chunk embedding (covert chunks to vectors)

# %%
embedding_model = SentenceTransformer(
    model_name_or_path='sentence-transformers/all-miniLM-L6-V2' 
)
chunk_embeddings = embedding_model.encode(chunks).astype('float32')
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2845.79it/s]

# %%
chunk_embeddings.shape
# Out:
# (15, 384)

# %%
dimension = chunk_embeddings.shape[1]
dimension
# Out:
# 384

# %%
faiss.normalize_L2(chunk_embeddings)

# %%
index_faiss_db = faiss.IndexFlat(dimension)
index_faiss_db.add(chunk_embeddings)  # vector bd

# %% [markdown]
# retrival part

# %%
def r_search(query , k=3):
    query_embeddings = embedding_model.encode(query).astype('float32')
    query_embeddings = query_embeddings.reshape(1,-1) #2d
    faiss.normalize_L2(query_embeddings)
    print(query_embeddings.shape)
    distance,index = index_faiss_db.search(query_embeddings,k=k) # retrival part
    R_chunk = [chunks[i] for i in index[0]]
    R_str = ' '.join(R_chunk)
    return R_str

# result = r_search('what is big data')
# print (result)

# to generate the structured way we use llm

# %%
print(r_search)
# Out:
# <function r_search at 0x000001F6096938A0>

# %% [markdown]
# gendration part

# %%
import os

def g_text(prompt):

    from langchain_google_genai import ChatGoogleGenerativeAI
    llm = ChatGoogleGenerativeAI(
        model = 'gemini-3.5-flash',
        api_key = os.environ["GOOGLE_API_KEY"]
    )

    prompt = f'''
                    You're an helpful assistant
                    Assigned Task for you : Structure my output => {prompt}
                    Note : 
                    1) Don't add extra contents just structure mentioned output.
                    2) If there is mistake in output correct or else keep the original output
                    with structured result.
            '''
    response = llm.invoke(prompt)
    return response.content[0]['text']
#send the request to gemini and get back the response
# response
user_prompt = 'Explain Machine Learning ?'
user_prompt = re.sub(r'[^0-9a-zA-Z\s]','',user_prompt)
response = r_search(user_prompt)
g_response = g_text(response)
# print(g_response) 


with open('g_response.txt','w') as file:
    file.write(g_response)
# Out:
# (1, 384)
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
# def g_text(r_search):
#         import os
#         import requests

#         API_URL = "https://router.huggingface.co/v1/chat/completions"
    
#         headers = {
#             "Authorization": f"Bearer {os.environ['HF_TOKEN']}",
#         }
#         def query(payload):
#             response = requests.post(API_URL, headers=headers, json=payload)
#             return response.json()
#         prompt = f'''
#                     You're an helpful assistant
#                     Assigned Task for you : Structure my output => {r_search}
#                     Note : 
#                     1) Don't add extra contents just structure mentioned output.
#                     2) If there is mistake in output correct or else keep the original output
#                     with structured result.
#             '''
#         response = query({
#             "messages": [
#                 {
#                     "role": "user",
#                     "content": f'{prompt}'
#                 }
#             ],
#             "model": "deepseek-ai/DeepSeek-R1:novita"
#         })
#         return response
# user_prompt = 'Explain Machine Learning ?'
# user_prompt = re.sub(r'[^0-9a-zA-Z\s]','',user_prompt)
# r_response = r_search(user_prompt)
# g_response = g_text(r_response)
# print(g_response)
